# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("oil_reserves.csv")

# %%
df.head()
# Out:
#                Region Country/ Region     2010     2011     2012     2013  \
# 0       North America              US   34.990   39.775   44.180   48.463
# 1       North America          Canada  174.848  174.177  173.716  173.038
# 2       North America          Mexico   11.691   11.394   11.424   11.079
# 3  S. & Cent. America       Argentina    2.524    2.525    2.354    2.330
# 4  S. & Cent. America          Brazil   14.246   15.050   15.314   15.593
#
#       2014     2015     2016
# 0   54.962   47.987   47.987
# 1  172.156  171.512  171.512
# 2   10.816    7.977    7.977
# 3    2.380    2.395    2.395
# 4   16.184   13.000   12.634

# %%
#Question 1.a
sum=df["2014"]+df["2015"]+df["2016"]
print(sum.max())
a=np.where(sum==sum.max())
new=df.iloc[a]
new["Country/ Region"]
# Out:
# 901.809
# 9    Venezuela
# Name: Country/ Region, dtype: object

# %%
#Q)1.f
import matplotlib.pyplot as plt

#import pandas as pd

#data = pd.read_csv('product.csv', index_col = False)


#plot data
plt.bar(df['Region'], df['2014'])

plt.bar(df['Region'], df['2015'])

plt.bar(df['Region'], df['2016'])



#labels
plt.xlabel("Year")
plt.ylabel("Number in units")

# add legend
plt.legend()

#title
plt.title("Oil Reserves In Various Regions")

# save plot as image
plt.savefig('oil.jpg')
# Out:
# No handles with labels found to put in legend.

# %%
#q)1.b
df["oil_allyear"]=df["2014"]+df["2015"]+df["2016"]+df["2012"]+df["2013"]+df["2010"]+df["2011"]

# %%
df[df["oil_allyear"].max() and df["Region"]=="North America"]
# Out:
#           Region Country/ Region     2010     2011     2012     2013     2014  \
# 0  North America              US   34.990   39.775   44.180   48.463   54.962
# 1  North America          Canada  174.848  174.177  173.716  173.038  172.156
# 2  North America          Mexico   11.691   11.394   11.424   11.079   10.816
#
#       2015     2016  oil_allyear
# 0   47.987   47.987      318.344
# 1  171.512  171.512     1210.959
# 2    7.977    7.977       72.358

# %%
print(df[df['Region']==df['oil_allyear'].max()])
# Out:
# Empty DataFrame
# Columns: [Region, Country/ Region, 2010, 2011, 2012, 2013, 2014, 2015, 2016, oil_allyear]
# Index: []

# %%
#Q)1.d
print(df.sort_values('2015',ascending=False)["Country/ Region"].head())
# Out:
# 9        Venezuela
# 27    Saudi Arabia
# 1           Canada
# 22            Iran
# 23            Iraq
# Name: Country/ Region, dtype: object

# %%
df1 = pd.read_csv("milk_production.csv")

# %%
df2=df1.fillna(0)

# %%
df2.head()
# Out:
#   Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 0    State     Andhra Pradesh            3102.0            3377.0
# 1    State  Arunachal Pradesh              28.0              22.0
# 2    State              Assam             666.0             658.0
# 3    State              Bihar            3561.0            3661.0
# 4    State       Chhattisgarh             644.0             701.0
#
#    Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  Boffalo Milk-2010-11  \
# 0            3799.0              3079              3369                8101.0
# 1              43.0                46                50                   0.0
# 2             677.0               685               703                 101.0
# 3            3986.0              4318              4881                2798.0
# 4             788.0               824               919                 343.0
#
#    Boffalo Milk-2011-12  Boffalo Milk-2013-14  Boffalo Milk-2014-15  \
# ...

# %%
#Q)2.a
df2["y2011"] =df2["Cow Milk-2010-11"] + df2["Boffalo Milk-2010-11"] + df2["Goat Milk-2010-11"]
df2["y2012"]= df2["Cow Milk-2011-12"] + df2["Boffalo Milk-2011-12"] + df2["Goat Milk-2011-12"]
df2["y2014"]= df2["Cow Milk-2013-14"] + df2["Boffalo Milk-2013-14"] + df2["Goat Milk-2013-14"]
df2["y2015"]= df2["Cow Milk-2014-15"] + df2["Boffalo Milk-2014-15"] + df2["Goat Milk-2014-15"]
df2["y2016"]= df2["Cow Milk-2015-16"] + df2["Boffalo Milk-2015-16"] + df2["Goat Milk-2015-16"]

# %%
print(df2.sort_values('y2014',ascending=False)["State/ UT Name"].head(1))
# Out:
# 26    Uttar Pradesh
# Name: State/ UT Name, dtype: object

# %%
#Q2.b
print(df2.sort_values('y2011',ascending=False)["State/ UT Name"].head(5))
print(df2.sort_values('y2012',ascending=False)["State/ UT Name"].head(5))
print(df2.sort_values('y2016',ascending=False)["State/ UT Name"].head(5))
print(df2.sort_values('y2014',ascending=False)["State/ UT Name"].head(5))
print(df2.sort_values('y2015',ascending=False)["State/ UT Name"].head(5))
# Out:
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 6            Gujarat
# Name: State/ UT Name, dtype: object
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 20            Punjab
# 14       Maharashtra
# Name: State/ UT Name, dtype: object
# 26     Uttar Pradesh
# 21         Rajasthan
# 6            Gujarat
# 13    Madhya Pradesh
# 0     Andhra Pradesh
# Name: State/ UT Name, dtype: object
# 26     Uttar Pradesh
# 21         Rajasthan
# 0     Andhra Pradesh
# 6            Gujarat
# 20            Punjab
# Name: State/ UT Name, dtype: object
# 26     Uttar Pradesh
# 21         Rajasthan
# 6            Gujarat
# 13    Madhya Pradesh
# 20            Punjab
# Name: State/ UT Name, dtype: object

# %%
#q.2.b

df2[df2["y2011"].mean() and df2["State/ UT Name"]=="Uttar Pradesh"]
# Out:
#    Category State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 26    State  Uttar Pradesh            5342.0            5837.0
#
#     Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  \
# 26            6142.0              6387              8243
#
#     Boffalo Milk-2010-11  Boffalo Milk-2011-12  Boffalo Milk-2013-14  ...  \
# 26               14496.0               15549.0               16805.0  ...
#
#     Goat Milk-2010-11  Goat Milk-2011-12  Goat Milk-2013-14  \
# 26             1193.0             1171.0             1248.0
#
#     Goat Milk-2014-15  Goat Milk-2015-16    y2011    y2012    y2014  y2015  \
# 26               1288               1279  21031.0  22557.0  24195.0  25199
#
#     y2016
# 26  26387
#
# [1 rows x 22 columns]

# %%
df2[df2["y2012"].mean() and df2["State/ UT Name"]=="Uttar Pradesh"]
# Out:
#    Category State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 26    State  Uttar Pradesh            5342.0            5837.0
#
#     Cow Milk-2013-14  Cow Milk-2014-15  Cow Milk-2015-16  \
# 26            6142.0              6387              8243
#
#     Boffalo Milk-2010-11  Boffalo Milk-2011-12  Boffalo Milk-2013-14  ...  \
# 26               14496.0               15549.0               16805.0  ...
#
#     Goat Milk-2010-11  Goat Milk-2011-12  Goat Milk-2013-14  \
# 26             1193.0             1171.0             1248.0
#
#     Goat Milk-2014-15  Goat Milk-2015-16    y2011    y2012    y2014  y2015  \
# 26               1288               1279  21031.0  22557.0  24195.0  25199
#
#     y2016
# 26  26387
#
# [1 rows x 22 columns]

# %%
#Q)2.d

print(df2[(df2["y2016"]>df2["y2015"])&(df2["y2015"]>df2["y2014"])&(df2["y2014"]>df2["y2012"])])
# Out:
#    Category     State/ UT Name  Cow Milk-2010-11  Cow Milk-2011-12  \
# 1     State  Arunachal Pradesh              28.0              22.0
# 2     State              Assam             666.0             658.0
# 3     State              Bihar            3561.0            3661.0
# 4     State       Chhattisgarh             644.0             701.0
# 6     State            Gujarat            3572.0            3848.0
# 7     State            Haryana             966.0             998.0
# 8     State   Himachal Pradesh             669.0             680.0
# 9     State    Jammu & Kashmir            1205.0            1204.0
# 11    State          Karnataka            3475.0            3715.0
# 13    State     Madhya Pradesh            3152.0            3589.0
# 14    State        Maharashtra            4297.0            4605.0
# 16    State          Meghalaya              77.0              78.0
# 17    State            Mizoram              11.0              14.0
# ...

# %%
#q2.e
import matplotlib.pyplot as plt
import pandas as pd

#data = pd.read_csv('product.csv', index_col = False)

Years=[2016,2013,2014]
#plot data
plt.plot(df2['y2016'],df2['State/ UT Name']=='Punjab',linestyle="solid")

plt.plot(df2['y2015'],df2['State/ UT Name']=='Punjab',linestyle="solid")

plt.plot(df2['y2014'],df2['State/ UT Name']=='Punjab',linestyle="solid")
plt.plot(df2['y2012'],df2['State/ UT Name']=='Punjab',linestyle="solid")
plt.plot(df2['y2011'],df2['State/ UT Name']=='Punjab',linestyle="solid")



#labels
plt.xlabel("Years")
plt.ylabel("Number in units")

# add legend
plt.legend()

#title
plt.title("Milk")

# save plot as image
plt.savefig('products.jpg')
# Out:
# No handles with labels found to put in legend.

# %%
#q2.f
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = ['y2011','y2012','y2014','y2015','y2016']
sizes = [30,15,20,30,10]
#explode = (0, 0, 0, 0)
explode = (0, 0.1,0,0,0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=135)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
