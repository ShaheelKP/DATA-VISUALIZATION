# %%
import pandas as pd
df=pd.read_csv('Accident_Cities.csv')
df.head()
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
# 3        Aurangabad                                   161.0
# 4         Bengaluru                                   689.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
# 3                 719.0                  173.0                   744.0
# 4                6031.0                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# ...

# %%
#1
df["injured"] =(df["Persons Injured - 2011"] + df["Persons Injured - 2012"] + df["Injured - 2013"])

# %%
df.head(3)
#new1[["Name of City","injured"]]
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# 1                                   245.0                1850.0
# 2                                   199.0                 380.0
#
#    Persons Killed - 2012  Persons Injured - 2012  Fatal Accidents - 2013  \
# 0                  427.0                   675.0                   436.0
# ...

# %%
df1=df.sort_values("injured", ascending = False) 
new1=df1.head(3)
new1[["Name of City","injured"]]
# Out:
#    Name of City  injured
# 7         Delhi  20957.0
# 27       Mumbai  13852.0
# 4     Bengaluru  13813.0

# %%
#2
df[df["Persons Injured - 2011"].ge(df["Persons Injured - 2012"])].head()
# Out:
#   Name of City  Total number of Fatal Accidents - 2011  All Accidents - 2011  \
# 0         Agra                                   336.0                1299.0
# 1    Ahmedabad                                   222.0                2020.0
# 3   Aurangabad                                   161.0                 719.0
# 4    Bengaluru                                   689.0                6031.0
# 6   Coimbatore                                   253.0                1126.0
#
#    Persons Killed - 2011  Persons Injured - 2011  \
# 0                  632.0                  1046.0
# 1                  227.0                  2036.0
# 3                  173.0                   744.0
# 4                  720.0                  4952.0
# 6                  259.0                  1058.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# 1                                   245.0                1850.0
# ...

# %%
#7
df[df["All Accidents - 2011"].ge(df["All Accidents - 2012"]) & df["All Accidents - 2012"].ge(df["Total Accidents - 2013"]) & df["Total Accidents - 2013"].ge(df["Total Accidents - 2014"]) & df["Total Accidents - 2014"].ge(df["Total Accidents - 2015"]) ]
# Out:
#   Name of City  Total number of Fatal Accidents - 2011  All Accidents - 2011  \
# 4    Bengaluru                                   689.0                6031.0
#
#    Persons Killed - 2011  Persons Injured - 2011  \
# 4                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 4                                   707.0                5508.0
#
#    Persons Killed - 2012  Persons Injured - 2012  Fatal Accidents - 2013  \
# 4                  725.0                  4527.0                   733.0
#
#     ...     Severity - 2014  Fatal Accidents - 2015  \
# 4   ...                14.6                   708.0
#
#    Greviously Injured Accidents - 2015  Minor Accidents - 2015  \
# 4                               1331.0                  1899.0
#
#    Non-Injurey Accidents - 2015  Total Accidents - 2015  Killed - 2015  \
# 4                         896.0                  4834.0          713.0
#
# ...

# %%
#5
df["death"] =(df["Persons Killed - 2011"] + df["Persons Killed - 2012"] + df["Killed - 2013"] + df["Killed - 2014"] + df["Killed - 2015"])

# %%
df2=df.sort_values("death", ascending = False) 
df2.head(3)
#df5=df2.head(3)
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  All Accidents - 2011  \
# 7         Delhi                                  2007.0                7281.0
# 4     Bengaluru                                   689.0                6031.0
# 27       Mumbai                                   539.0               25471.0
#
#     Persons Killed - 2011  Persons Injured - 2011  \
# 7                  2065.0                  7226.0
# 4                   720.0                  4952.0
# 27                  563.0                  5059.0
#
#     Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 7                                   1822.0                6937.0
# 4                                    707.0                5508.0
# 27                                   471.0               24592.0
#
#     Persons Killed - 2012  Persons Injured - 2012  Fatal Accidents - 2013  \
# 7                  1866.0                  6633.0                  1778.0
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

#objects = ['Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp']
#x_pos = np.arange(len(objects))
#performance = [8, 6, 4, 3, 2, 1]

plt.bar(df2['Name of City'], df2['death'])
plt.xticks(df2['Name of City'])
plt.xlabel('CITIES')
plt.ylabel('DEATHS')
plt.title('HIGHEST DEATH')

plt.show()

# %%
#6
df["deathdueaccidents"] =(df["Persons Killed - 2011"] + df["Persons Killed - 2012"] + df["Killed - 2013"] + df["Killed - 2014"] + df["Killed - 2015"])

# %%
df9=df[['Name of City','deathdueaccidents']]
#df9
df9.iloc[[4,7,19,27,23]]
# Out:
#    Name of City  deathdueaccidents
# 4     Bengaluru             3639.0
# 7         Delhi             9044.0
# 19      Kolkata             2225.0
# 27       Mumbai             2698.0
# 23      Lucknow             2550.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-96406918152c> in <module>()
#       1 index_ = ['Row_1']
# ----> 2 df10.index = index_
#
# NameError: name 'df10' is not defined

# %%
dnew=pd.read_csv('Accident_States.csv')
dnew.head()
# Out:
#           Unnamed: 0                                         Unnamed: 1  \
# 0         States/UTs  State/UT-Wise Total Number of Persons Injured ...
# 1     Andhra Pradesh                                              52157
# 2  Arunachal Pradesh                                                530
# 3              Assam                                               5522
# 4              Bihar                                               7113
#
#                                           Unnamed: 2  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              53928
# 2                                                491
# 3                                               7579
# 4                                               8106
#
#                                           Unnamed: 3  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              55583
# ...

# %%
#3

new_header = dnew.iloc[0] #grab the first row for the header
dnew = dnew[1:] #take the data less the header row
dnew.columns = new_header #set the header row as the df header

# %%
dnew.head(2)
# Out:
# 0         States/UTs  \
# 1     Andhra Pradesh
# 2  Arunachal Pradesh
#
# 0 State/UT-Wise Total Number of Persons Injured in Road Accidents during-2009  \
# 1                                              52157
# 2                                                530
#
# 0 State/UT-Wise Total Number of Persons Injured in Road Accidents during-2010  \
# 1                                              53928
# 2                                                491
#
# 0 State/UT-Wise Total Number of Persons Injured in Road Accidents during-2011  \
# 1                                              55583
# 2                                                438
#
# 0 State/UT-Wise Total Number of Persons Injured in Road Accidents during-2012  \
# 1                                              51552
# 2                                                399
#
# 0  2008.0  2009.0  2010.0  2011.0  2012.0  ...   2016  2008.0  2009.0  2010.0  \
# ...

# %%
dnew[[2008.0]]
# Out:
# 0   2008.0  2008.0
# 1   7471.0  1591.0
# 2     32.0    25.0
# 3    843.0   530.0
# 4   1008.0  1944.0
# 5   1347.0   855.0
# 6    271.0    42.0
# 7   4373.0   540.0
# 8   2580.0   427.0
# 9    388.0    34.0
# 10   603.0   378.0
# 11   633.0   725.0
# 12  5678.0   513.0
# 13  2317.0    67.0
# 14  4034.0  1899.0
# 15  8704.0  2169.0
# 16    22.0   105.0
# 17    69.0     9.0
# 18    35.0    18.0
# 19    25.0     9.0
# 20  1330.0   819.0
# 21  1478.0   130.0
# 22  4736.0  1132.0
# 23    28.0    52.0
# 24  5703.0   363.0
# 25     NaN     NaN
# 26   175.0    23.0
# 27   575.0     9.0
# 28  2803.0  4155.0
# 29  1670.0  1555.0
# 30    15.0    23.0
# 31    20.0     4.0
# 32    65.0     0.0
# 33     5.0     1.0
# 34     0.0     0.0
# 35     0.0     0.0
# 36   210.0     4.0

# %%
dnew.rename(index={0:'zero',1:'one'}, inplace=True)
